# %% [markdown]
# # Chapter 4
# ## Damped Oscillations

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mplines

# %%
t = np.linspace(0,12*np.pi,200)
omega_1 = 1
delta_1 = 0
delta_2 = 3.14
A_0 = 5
tau = 10

def shm(thing, shift):
    x = A_0*np.cos(omega_1*thing + shift)
    return x

def damp(t):
    damp = np.exp(-t/(2*tau))
    return damp

#plt.xkcd(scale=5, length=3500, randomness=20)

fig = plt.figure(figsize=(7,5))

ax = plt.axes()


ax.set_ylabel('Displacement, $y$')
ax.set_xlabel('Time, $t$')

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")
#plt.text(10, 4,'Phase shift, $\delta = $'+str(delta_2), ha="right", va="center", size=10)
ax.plot(t, shm(t,delta_1)*damp(t),color='blue')
ax.plot(t, A_0*damp(t),color='orange',linestyle='--')
ax.plot(t, -A_0*damp(t),color='orange',linestyle='--')
ax.plot(t, shm(t,delta_1),color='gray',linestyle='dotted')

ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.plot(t, shm(t,delta_2),color='orange')

ax.set_xlim(0,)
#ax.set_ylim(0,)

plt.tight_layout()
plt.savefig('ch4-dampedoscill1.pdf',transparent=True)
plt.savefig('ch4-dampedoscill1.png',transparent=True)
plt.savefig('ch4-dampedoscill1.svg',transparent=True)
plt.show()

# %%
t = np.linspace(0,12*np.pi,200)
omega_1 = 1
delta_1 = 0
delta_2 = 3.14
A_0 = 5
tau = 10

def shm(thing, shift):
    x = A_0*np.cos(omega_1*thing + shift)
    return x

def damp(t):
    damp = np.exp(-t/(2*tau))
    return damp

#plt.xkcd(scale=5, length=3500, randomness=20)

fig = plt.figure(figsize=(5,3))

ax = plt.axes()


ax.set_ylabel('Displacement, $y$')
ax.set_xlabel('Time, $t$')

plt.axvline(x=0,linewidth=1,color='k',linestyle="-")
plt.axhline(y=0,linewidth=1,color='k',linestyle="-")
#plt.text(10, 4,'Phase shift, $\delta = $'+str(delta_2), ha="right", va="center", size=10)
ax.plot(t, shm(t,delta_1)*damp(t),color='blue')
ax.plot(t, A_0*damp(t),color='orange',linestyle='--')
ax.plot(t, -A_0*damp(t),color='orange',linestyle='--')
#ax.plot(t, shm(t,delta_1),color='gray',linestyle='dotted')

ax.set_xticklabels([])
ax.set_yticklabels([])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
#ax.plot(t, shm(t,delta_2),color='orange')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

ax.set_xlim(0,)
#ax.set_ylim(0,)

plt.tight_layout()
plt.savefig('ch4-dampedoscill2.pdf',transparent=True)
plt.savefig('ch4-dampedoscill2.png',transparent=True)
plt.savefig('ch4-dampedoscill2.svg',transparent=True)
plt.show()

# %%
# Trying critical and overdamping again

t = np.linspace(0,7,100)
omega_0 = 1
delta_1 = 0
A_0 = 5
m = 1
b_c = 2*m*omega_0
b = 0.1*b_c
tau = m/b

omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2 )

def omega_prime(damp):
    omega_prime = np.sqrt(omega_0**2 - (0.5*damp/m)**2 )
    return omega_prime

def damp_shm(time,damp):
    x = A_0*np.cos(omega_prime(damp)*time + delta_1) * np.exp(-(0.5*damp*time/m))
    return x

def overdamp(thing,shift):
    x = 0.5*A_0*np.cos(0.45*thing+shift)+0.5*A_0
    return x

fig = plt.figure(figsize=(7,5))

ax = plt.axes()

ax.set_ylabel('Displacement, $x$')
ax.set_xlabel('Time, $t$')

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

#plt.text(10, 4,'Phase shift, $\delta = $'+str(delta_2), ha="right", va="center", size=10)
ax.plot(t, damp_shm(t,0*b_c),color='gray',label='No damping',linestyle='dotted')
ax.plot(t, damp_shm(t,0.2*b_c),color='black',label='Light damping',linestyle='dotted')
ax.plot(t, damp_shm(t,1*b_c),color='blue',label='Critically damped')
ax.plot(t, overdamp(t,delta_1),color='orange',linestyle='--',label='Overdamped')



#ax.plot(t, overdamp(t,delta_1),color='orange',linestyle='--',label='Overdamped')
#ax.plot(t, A_0*damp(t),color='orange',linestyle='--')
#ax.plot(t, -A_0*damp(t),color='orange',linestyle='--')
#ax.plot(t, shm(t,delta_1),color='gray',linestyle='dotted')

ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.plot(t, shm(t,delta_2),color='orange')
#ax.set_xlim(0,)
#ax.set_ylim(0,)

ax.legend()
plt.tight_layout()
plt.savefig('ch4-critoverdamp2.pdf',transparent=True)
plt.savefig('ch4-critoverdamp2.png',transparent=True)
plt.savefig('ch4-critoverdamp2.svg',transparent=True)
plt.show()

# %%
t = np.linspace(0,2*np.pi,100)
omega_0 = 1
delta_1 = 0
A_0 = 5
m = 1
b_c = 2*m*omega_0
tau = m/b
b = b_c


def omega_prime(w,damp):
        omega_prime = np.sqrt(w**2 - (0.5*damp/m)**2)
        return omega_prime

def damp_shm(thing, shift,w,damp):
    x = A_0*np.cos(omega_prime(w,damp)*thing + shift)*np.exp(-(t*damp)/(2*m))
    return x

def overdamp(thing,shift):
    x = 0.5*A_0*np.cos(0.45*thing+shift)+0.5*A_0
    return x

#plt.xkcd(scale=5, length=3500, randomness=20)

fig = plt.figure(figsize=(7,5))

ax = plt.axes()


ax.set_ylabel('Displacement, $x$')
ax.set_xlabel('Time, $t$')

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")
#plt.text(10, 4,'Phase shift, $\delta = $'+str(delta_2), ha="right", va="center", size=10)
ax.plot(t, damp_shm(t,delta_1,omega_0,b),color='blue',label='Critically damped')
ax.plot(t, overdamp(t,delta_1),color='orange',linestyle='--',label='Overdamped')
#ax.plot(t, A_0*damp(t),color='orange',linestyle='--')
#ax.plot(t, -A_0*damp(t),color='orange',linestyle='--')
#ax.plot(t, shm(t,delta_1),color='gray',linestyle='dotted')

ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.plot(t, shm(t,delta_2),color='orange')
ax.set_xlim(0,)
ax.set_ylim(0,)

ax.legend()
plt.tight_layout()
plt.savefig('ch4-critoverdamp1.pdf',transparent=True)
plt.savefig('ch4-critoverdamp1.png',transparent=True)
plt.savefig('ch4-critoverdamp1.svg',transparent=True)
plt.show()

# %% [markdown]
# # Chapter 5
# ## Forced oscillations

# %%
t = np.linspace(0,4*np.pi,200)
omega_0r = np.linspace(0,10,200)
b = np.arange(1,7)
m = 1
omega_0 = 3
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((b*omega )/(m*(omega_0**2 - omega**2)))
    return delta

fig = plt.figure(figsize=(7,5))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

for n in b:
    ax.plot(omega_0r,amp_f(omega_0r,n),color=colors[n-1],label='b = '+str(n))
#    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')


    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Amplitude of oscillation, $A$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xlim(0,)
ax.set_ylim(0,)

ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.plot(t, shm(t,delta_2),color='orange')

ax.legend()
plt.tight_layout()
plt.savefig('ch5-forcedosc1.pdf',transparent=True)
plt.savefig('ch5-forcedosc1.png',transparent=True)
plt.savefig('ch5-forcedosc1.svg',transparent=True)
plt.show()

# %%
t = np.linspace(0,4*np.pi,200)
omega_0r = np.linspace(0,10,200)
b = np.arange(1,7)
m = 1
omega_0 = 3
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((b*omega )/(m*(omega_0**2 - omega**2)))
    return delta

fig = plt.figure(figsize=(6,4))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

for n in b:
    ax.plot(omega_0r,amp_f(omega_0r,n/4),color=colors[n-1],label='b = '+str(n/4))
#    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n/4))],np.max(amp_f(omega_0r,n/4)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')


    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Amplitude of oscillation, $A$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xlim(0,)
ax.set_ylim(0,)

ax.set_xticklabels([])
ax.set_yticklabels([])
#ax.plot(t, shm(t,delta_2),color='orange')

ax.legend()
plt.tight_layout()
plt.savefig('slides-forcedosc1.pdf',transparent=True)
plt.savefig('slides-forcedosc1.png',transparent=True)
plt.savefig('slides-forcedosc1.svg',transparent=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
t = np.linspace(0,4*np.pi,200)
omega_0r = np.linspace(0,10,200)
b = np.arange(1,7)
m = 1
omega_0 = 3
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((b*omega )/(m*(omega_0**2 - omega**2)))
    return delta

##### FINDING FWHM, via https://stackoverflow.com/questions/49100778/fwhm-calculation-using-python

def lin_interp(x, y, i, half):
    return x[i] + (x[i+1] - x[i]) * ((half - y[i]) / (y[i+1] - y[i]))

def half_max_x(x, y):
    half = max(y)/2.0
    signs = np.sign(np.add(y, -half))
    zero_crossings = (signs[0:-2] != signs[1:-1])
    zero_crossings_i = np.where(zero_crossings)[0]
    return [lin_interp(x, y, zero_crossings_i[0], half),
            lin_interp(x, y, zero_crossings_i[1], half)]


fig = plt.figure(figsize=(7,5))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

for n in b:
    power_data=omega_0r*(amp_f(omega_0r,n))**2
    ax.plot(omega_0r,power_data,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

###### FWHM

for n in [1,2]:
    power_data=omega_0r*(amp_f(omega_0r,n))**2
    hmx = half_max_x(omega_0r,power_data)
    half = max(power_data)/2
    delta_omega=hmx[1]-hmx[0]
    ax.plot(hmx,[half,half],linestyle='--',color=colors[n-1],label="$\Delta \omega$ = "+str(np.around(delta_omega,decimals=2)))
    ax.text((hmx[0]+hmx[1])/2,half+0.05,'$\Delta \omega $',ha="center", va="center",size=20)
    
##### END FWHM

    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Average power transfer per cycle, $P_{av}$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xticklabels([])
#ax.set_yticklabels([])

ax.set_xlim(0,)
ax.set_ylim(0,)

ax.legend()
plt.tight_layout()
plt.savefig('ch5-forcedosc2.pdf',transparent=True)
plt.savefig('ch5-forcedosc2.png',transparent=True)
plt.savefig('ch5-forcedosc2.svg',transparent=True)
plt.show()

# %%
t = np.linspace(0,4*np.pi,200)
omega_0r = np.linspace(0,10,200)
b = np.arange(1,5)
m = 1
omega_0 = 3
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((b*omega )/(m*(omega_0**2 - omega**2)))
    return delta

##### FINDING FWHM, via https://stackoverflow.com/questions/49100778/fwhm-calculation-using-python

def lin_interp(x, y, i, half):
    return x[i] + (x[i+1] - x[i]) * ((half - y[i]) / (y[i+1] - y[i]))

def half_max_x(x, y):
    half = max(y)/2.0
    signs = np.sign(np.add(y, -half))
    zero_crossings = (signs[0:-2] != signs[1:-1])
    zero_crossings_i = np.where(zero_crossings)[0]
    return [lin_interp(x, y, zero_crossings_i[0], half),
            lin_interp(x, y, zero_crossings_i[1], half)]


fig = plt.figure(figsize=(6,4))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

for n in b:
    power_data=omega_0r*(amp_f(omega_0r,n))**2
    ax.plot(omega_0r,power_data,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

###### FWHM

for n in [1,2]:
    power_data=omega_0r*(amp_f(omega_0r,n))**2
    hmx = half_max_x(omega_0r,power_data)
    half = max(power_data)/2
    delta_omega=hmx[1]-hmx[0]
    ax.plot(hmx,[half,half],linestyle='--',color=colors[n-1],label="$\Delta \omega$ = "+str(np.around(delta_omega,decimals=2)))
    ax.text((hmx[0]+hmx[1])/2,half+0.05,'$\Delta \omega $',ha="center", va="center",size=20)
    
##### END FWHM

    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Average power transfer per cycle, $P_{av}$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xticklabels([])
#ax.set_yticklabels([])

ax.set_xlim(0,)
ax.set_ylim(0,)

ax.legend()
plt.tight_layout()
plt.savefig('slides-forcedosc2.pdf',transparent=True)
plt.savefig('slides-forcedosc2.png',transparent=True)
plt.savefig('slides-forcedosc2.svg',transparent=True)
plt.show()

# %%
power_data1=omega_0r*(amp_f(omega_0r,n))**2
max_power_loc = np.argmax(power_data1)
power_max = power_data1[max_power_loc]
half_max = power_data1[max_power_loc]/2
np.where(power_data1 == [power_max])
# Out:
# (array([56]),)

# %%
t = np.linspace(0,3*np.pi,200)
omega_0r = np.linspace(0,7.5,400)
b = np.arange(1,7)
m = 1
omega_0 = 4
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((damp*omega )/(m*(omega_0**2 - omega**2)))
    return delta

fig = plt.figure(figsize=(4,3))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

#for n in b:
#    ax.plot(omega_0r,amp_f(omega_0r,n),color=colors[n-1],label='b = '+str(n))
#    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

part1x = omega_0r[:np.argmax(delta_f(omega_0r,1))]
part1y = delta_f(omega_0r,1)[:np.argmax(delta_f(omega_0r,1))]

part2x = omega_0r[np.argmin(delta_f(omega_0r,1)):]
part2y = np.pi-abs(delta_f(omega_0r,1)[np.argmin(delta_f(omega_0r,1)):])

omega_scale = np.concatenate((part1x,part2x), axis=0)
phase_offset = np.concatenate((part1y,part2y), axis=0)

ax.plot(omega_scale,phase_offset,color=colors[0],label='b = '+str(n))

#ax.plot(omega_0r[np.argmin(delta_f(omega_0r,1)):],np.pi-abs(delta_f(omega_0r,1)[np.argmin(delta_f(omega_0r,1)):]),color=colors[0],label='b = '+str(n))



#ax.plot(omega_0r,np.pi-abs(delta_f(omega_0r,1)),color=colors[1],label='b = '+str(n))
    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
#ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")
ax.axhline(y=np.pi/2,linewidth=0.5,color='r',linestyle="--")
ax.text(omega_0,0.2,'$\omega_0$',ha="center", va="center",size=20)
ax.text(0.2,np.pi/2,'$\pi / 2$',ha="left", va="bottom",size=20)

plt.plot([omega_0,omega_0],[0,np.pi/2],color='red',linestyle="dotted",linewidth=0.5)



plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Phase offset, $\delta$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xticklabels([])
ax.set_yticklabels([])

ax.set_xlim(0,)
ax.set_ylim(0,)

#ax.legend()
plt.tight_layout()
plt.savefig('slides-forcedosc3.pdf',transparent=True)
plt.savefig('slides-forcedosc3.png',transparent=True)
plt.savefig('slides-forcedosc3.svg',transparent=True)
plt.show()

# %%
t = np.linspace(0,4*np.pi,200)
omega_0r = np.linspace(0,10,400)
b = np.arange(1,7)
m = 1
omega_0 = 4
omega_F = 1.5 # Forced oscillator frequency; usually just omega
F_0 = 2
omega_prime = np.sqrt(omega_0**2 - (0.5*b/m)**2)
#delta = np.arctan((b*omega_F )/(m*(omega_0**2 - omega_F**2)))

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def delta_f(omega,damp):
    delta = np.arctan((damp*omega )/(m*(omega_0**2 - omega**2)))
    return delta

fig = plt.figure(figsize=(7,5))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

#for n in b:
#    ax.plot(omega_0r,amp_f(omega_0r,n),color=colors[n-1],label='b = '+str(n))
#    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)

    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

part1x = omega_0r[:np.argmax(delta_f(omega_0r,1))]
part1y = delta_f(omega_0r,1)[:np.argmax(delta_f(omega_0r,1))]

part2x = omega_0r[np.argmin(delta_f(omega_0r,1)):]
part2y = np.pi-abs(delta_f(omega_0r,1)[np.argmin(delta_f(omega_0r,1)):])

omega_scale = np.concatenate((part1x,part2x), axis=0)
phase_offset = np.concatenate((part1y,part2y), axis=0)

ax.plot(omega_scale,phase_offset,color=colors[0],label='b = '+str(n))

#ax.plot(omega_0r[np.argmin(delta_f(omega_0r,1)):],np.pi-abs(delta_f(omega_0r,1)[np.argmin(delta_f(omega_0r,1)):]),color=colors[0],label='b = '+str(n))



#ax.plot(omega_0r,np.pi-abs(delta_f(omega_0r,1)),color=colors[1],label='b = '+str(n))
    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
#ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")
ax.axhline(y=np.pi/2,linewidth=0.5,color='r',linestyle="--")
ax.text(omega_0,0.2,'$\omega_0$',ha="center", va="center",size=20)
ax.text(0.2,np.pi/2,'$\pi / 2$',ha="left", va="bottom",size=20)

plt.plot([omega_0,omega_0],[0,np.pi/2],color='red',linestyle="dotted",linewidth=0.5)



plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Phase offset, $\delta$')
ax.set_xlabel('Driving frequency, $\omega$')

ax.set_xticklabels([])
ax.set_yticklabels([])

ax.set_xlim(0,)
ax.set_ylim(0,)

#ax.legend()
plt.tight_layout()
plt.savefig('ch5-forcedosc3.pdf',transparent=True)
plt.savefig('ch5-forcedosc3.png',transparent=True)
plt.savefig('ch5-forcedosc3.svg',transparent=True)
plt.show()

# %% [markdown]
# ### Forced oscillator, special cases:

# %%
# 1. omega << omega 0

t = np.linspace(0,14*np.pi,200)
omega_0 = 5
omega_prime = 0.9*omega_0
omega_F = 0.1*omega_0
F_0 = 2



m = 1
b = 0.3
delta_F = 0.2*np.pi

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def displacement_x(omega, damp,t):
    x = amp_f(omega,damp)*(np.cos(omega*t - delta_F) - np.exp(-damp*t/(2*m))*np.cos(omega_prime*t - delta_F))
    return x

fig = plt.figure(figsize=(6,4))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

#for n in b:
#    ax.plot(omega_0r,amp_f(omega_0r,n),color=colors[n-1],label='b = '+str(n))
##    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)
#
    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

ax.plot(t[0:],displacement_x(omega_F,b,t[0:]),color='blue',label='$\omega \ll \omega_0$')
# ax.plot(t,displacement_x(omega_F,b,t),color='gray',linestyle='dotted',label='$\omega \ll \omega_0$')


ax.plot(t,displacement_x(20*omega_F,b,t),color='orange',label='$\omega \gg \omega_0$')
#ax.plot(t,displacement_x(10*omega_F,b,t),color='red',label='$\omega \approx \omega_0$')




    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
#ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Displacement, $x$')
ax.set_xlabel('Time $t$')

ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlim(0,)
#ax.plot(t, shm(t,delta_2),color='orange')

ax.legend()
plt.tight_layout()
plt.savefig('ch5-forcedosc4.pdf',transparent=True)
plt.savefig('ch5-forcedosc4.png',transparent=True)
plt.savefig('ch5-forcedosc4.svg',transparent=True)
#plt.savefig('slides-forcedosc4c.pdf',transparent=True)
#plt.savefig('slides-forcedosc4c.png',transparent=True)
#plt.savefig('slides-forcedosc4c.svg',transparent=True)
plt.show()

# %%
# 1. omega << omega 0

t = np.linspace(0,8*np.pi,400)
omega_0 = 5
omega_prime = 0.9*omega_0
omega_F = 0.1*omega_0

m = 1
b = 0.3
delta_F = 0.2*np.pi

def amp_f(omega,damp):
    amp = F_0/(np.sqrt((m*(omega_0**2 - omega**2)**2)+(damp*omega)**2))
    return amp

def displacement_x(damp,t):
    x = amp_f(omega_0,damp)*(np.cos(omega_0*t - delta_F)*(1 - np.exp(-damp*t/(2*m))))
    return x

def exp_fit(damp,t):
    fit = amp_f(omega_0,damp)*(1 - np.exp(-damp*t/(2*m)))
    return fit

fig = plt.figure(figsize=(7,5))

colors=['b', 'g', 'r', 'c', 'm', 'y', 'k']

ax = plt.axes()

#for n in b:
#    ax.plot(omega_0r,amp_f(omega_0r,n),color=colors[n-1],label='b = '+str(n))
##    ax.plot(omega_0r,omega_0r*(amp_f(omega_0r,n))**2,color=colors[n-1],label='b = '+str(n)) #Power propto omega * A**2
#    ax.plot(omega_0r[np.argmax(amp_f(omega_0r,n))],np.max(amp_f(omega_0r,n)),'o',color=colors[n-1],markersize=5)
#
    
#    ax.plot(x[sample_point],y[sample_point],'ro',markersize='10')

#ax.plot(t,displacement_x(omega_F,b,t),color='blue',label='$\omega \ll \omega_0$')
#ax.plot(t,displacement_x(20*omega_F,b,t),color='orange',label='$\omega \gg \omega_0$')
ax.plot(t,displacement_x(b,t),color='blue',label='$\omega = \omega_0$')
ax.plot(t,exp_fit(b,t),color='orange',linestyle='--',label='Exponential fit')
ax.plot(t,-exp_fit(b,t),color='orange',linestyle='--')








    
#ax.plot(omega_0r,amp_f(omega_0r,2*b),color='orange',label='Heavily damped, low Q')
#ax.axvline(x=omega_0,linewidth=0.5,color='r',linestyle="--")

plt.axvline(x=0,linewidth=0.5,color='k',linestyle="--")
plt.axhline(y=0,linewidth=0.5,color='k',linestyle="--")

ax.set_ylabel('Displacement, $x$')
ax.set_xlabel('Time $t$')

ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlim(0,)
#ax.plot(t, shm(t,delta_2),color='orange')

ax.legend()
plt.tight_layout()
plt.savefig('ch5-forcedosc5.pdf',transparent=True)
plt.savefig('ch5-forcedosc5.png',transparent=True)
plt.savefig('ch5-forcedosc5.svg',transparent=True)
plt.show()

# %% [markdown]
# # TESTING

# %%
# FWHM finding

def peak(x, c):
    return np.exp(-np.power(x - c, 2) / 16.0)

def lin_interp(x, y, i, half):
    return x[i] + (x[i+1] - x[i]) * ((half - y[i]) / (y[i+1] - y[i]))

def half_max_x(x, y):
    half = max(y)/2.0
    signs = np.sign(np.add(y, -half))
    zero_crossings = (signs[0:-2] != signs[1:-1])
    zero_crossings_i = np.where(zero_crossings)[0]
    return [lin_interp(x, y, zero_crossings_i[0], half),
            lin_interp(x, y, zero_crossings_i[1], half)]

# make some fake data
x=np.linspace(0,20,21)
y=peak(x,10)

# find the two crossing points
hmx = half_max_x(x,y)

# print the answer
fwhm = hmx[1] - hmx[0]
print("FWHM:{:.3f}".format(fwhm))

# a convincing plot
half = max(y)/2.0
plt.plot(x,y)
plt.plot(hmx, [half, half])
plt.show()
# Out:
# FWHM:6.691
